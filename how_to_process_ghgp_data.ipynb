# %%
import importlib
import pandas as pd
import functions

importlib.reload(functions)
# Out:
# <module 'functions' from 'c:\\Users\\aange\\OneDrive\\Desktop\\stealth-energy\\epa-emissions\\functions.py'>

# %%
# loading in 2021 ghgp emission data
# we are skipping first 3 rows as they are just comments

'''
2021 GHGP Emissions data has the following tabs:
(1) Direct Emitters
(2) Onshore Oil & Gas Prod. 
(3) Gathering and Boosting
(4) Transmission Pipelines
(5) LDC - Direct Emissions
(6) SF6 from Elec. Equip.
(7) Suppliers
(8) CO2 Injection
(9) Geological Sequestration of CO2
(10) Industry Type
(11) FAQs about this Data
'''

# allows us to change the year of data we want to pull
year = '2021'

# direct emitters sheet
dems = pd.read_excel(f'ghgp_data_files/ghgp_data_{year}.xlsx', 
                        sheet_name='Direct Emitters', skiprows=3)

# onshore oil and gas production sheet
ogp = pd.read_excel(f'ghgp_data_files/ghgp_data_{year}.xlsx', 
                        sheet_name='Onshore Oil & Gas Prod.', skiprows=3)

# gathering and processing sheet
gb = pd.read_excel(f'ghgp_data_files/ghgp_data_{year}.xlsx', 
                        sheet_name='Gathering & Boosting', skiprows=3)

# transmission pipelines
tp = pd.read_excel(f'ghgp_data_files/ghgp_data_{year}.xlsx', 
                        sheet_name='Transmission Pipelines', skiprows=3)

# LDC - Direct Emissions sheet
ldc = pd.read_excel(f'ghgp_data_files/ghgp_data_{year}.xlsx', 
                        sheet_name='LDC - Direct Emissions', skiprows=3)

# sf6 from electricial equipment sheet
sf_six = pd.read_excel(f'ghgp_data_files/ghgp_data_{year}.xlsx', 
                        sheet_name='SF6 from Elec. Equip.', skiprows=3)

# suppliers sheet
sup = pd.read_excel(f'ghgp_data_files/ghgp_data_{year}.xlsx', 
                        sheet_name='Suppliers', skiprows=3)

# carbon dioxide injection sheet
carbs = pd.read_excel(f'ghgp_data_files/ghgp_data_{year}.xlsx', 
                        sheet_name='CO2 Injection', skiprows=3)

# %%
# processing direct emitter data now

# we need to create a path for both where we will be saving maps and processed file
dems_path = f"ghgp_processed/data_files/{year}_direct_emitters.xlsx"
dems_map = f"ghgp_processed/maps/{year}_direct_emitters.html"

# processing our files now
functions.black_box(data=dems, minimum_e=1_000, river_c=[], 
         save_excel=dems_path, save_map=dems_map)
# Out:
# Both column names not found!
# 1004377
# 1010040
# 1000112
# 1003742
# 1003188
# 1005043
# 1003739
# 1007698
# 1004206
# 1006665
# 1004836
# 1003408
# 1004914
# 1004804
# 1013282
# 1001106
# 1004680
# 1000766
# 1000767
# 1001033
# 1012058
# 1013527
# 1002983
# 1007514
# 1004511
# 1005353
# 1006971
# 1002627
# 1006529
# 1004761
# 1005601
# 1005046
# 1002731
# 1003752
# 1003422
# 1002154
# 1006208
# 1006047
# 1010610
# 1011855
# 1000376
# 1006080
# 1000034
# 1014236
# 1011961
# 1001991
# 1001633
# 1001636
# 1006790
# 1002094
# 1001845
# 1003038
# 1006979
# 1001637
# 1006963
# 1000627
# 1000630
# 1005310
# 1001444
# 1005972
# 1001447
# 1001450
# 1001223
# 1003853
# 1007551
# 1002069
# 1002070
# 1006054
# 1002408
# 1002291
# 1007333
# 1002067
# 1005284
# 1002380
# 1004236
# 1001919
# 1006430
# 1003724
# 1003730
# 1003780
# 1003910
# 1006115
# 1003591
# 1003748
# 1003013
# 1002698
# 1003009
# 1002121
# 1002122
# 1005809
# 1002727
# 1002123
# 1002430
# 1002257
# 1002435
# 1006088
# ...
